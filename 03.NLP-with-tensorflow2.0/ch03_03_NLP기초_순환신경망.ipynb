# %% [markdown]
# <a href="https://colab.research.google.com/github/PomesHouse/SkillTreePython-DeepLearning/blob/main/03.NLP-with-tensorflow2.0/ch03_03_NLP%EA%B8%B0%EC%B4%88_%EC%88%9C%ED%99%98%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch03.03 NLP기초 - 순환 신경망
# ---
#
# * 날짜:
# * 이름:
#
#
# ## 학습내용
#     - 순환 신경망에 대해 이해한다.
#     - RNN
#     - GRU
#     - LSTM

# %% [markdown]
# ```
# ! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# ```

# %%
! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# Out:
# Cloning into 'SkillTreePython-DeepLearning'...
# remote: Enumerating objects: 714, done.
# remote: Counting objects: 100% (287/287), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 714 (delta 176), reused 255 (delta 155), pack-reused 427
# Receiving objects: 100% (714/714), 38.09 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (369/369), done.

# %% [markdown]
# ```
# import sys
# sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
# from import_lib import *
# from plot_result import *
# ```

# %%
import sys
sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
from import_lib import *
from plot_result import *

# %% [markdown]
# ## imdb 베이스 모델
# ---

# %% [markdown]
# ### **| imdb 데이터 처리**
# ```
# MAX_LEN = 256
# MAX_FEATURES = 10000
#
# imdb = tf.keras.datasets.imdb
# (x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
# x_train = preprocessing.sequence.pad_sequences(x_train,
#                                                padding='post',
#                                                maxlen=MAX_LEN)
#
# x_test = preprocessing.sequence.pad_sequences(x_test,
#                                               padding='post',
#                                               maxlen=MAX_LEN)
# print(x_train.shape, x_test.shape)
# ```

# %%
MAX_LEN = 256
MAX_FEATURES = 10000

imdb = tf.keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
x_train = preprocessing.sequence.pad_sequences(x_train,
                                               padding='post',
                                               maxlen=MAX_LEN)

x_test = preprocessing.sequence.pad_sequences(x_test,
                                              padding='post',
                                              maxlen=MAX_LEN)
print(x_train.shape, x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step
# (25000, 256) (25000, 256)

# %% [markdown]
# ### **| FCN with GlobalAveragePooling1D**

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'FCNwithGAP')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "FCNwithGAP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256)]             0
#
#  embedding_1 (Embedding)     (None, 256, 32)           320000
#
#  global_average_pooling1d_1   (None, 32)               0
#  (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 320,033
# Trainable params: 320,033
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 5s 5ms/step - loss: 0.6808 - acc: 0.6759 - val_loss: 0.6640 - val_acc: 0.7700
# Epoch 2/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.6436 - acc: 0.7721 - val_loss: 0.6195 - val_acc: 0.7832
# Epoch 3/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.5949 - acc: 0.7937 - val_loss: 0.5694 - val_acc: 0.7958
# Epoch 4/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.5424 - acc: 0.8166 - val_loss: 0.5200 - val_acc: 0.8144
# Epoch 5/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4914 - acc: 0.8360 - val_loss: 0.4747 - val_acc: 0.8288
# Epoch 6/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4445 - acc: 0.8519 - val_loss: 0.4355 - val_acc: 0.8436
# Epoch 7/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4040 - acc: 0.8641 - val_loss: 0.4029 - val_acc: 0.8558
# Epoch 8/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3700 - acc: 0.8736 - val_loss: 0.3770 - val_acc: 0.8588
# Epoch 9/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3419 - acc: 0.8811 - val_loss: 0.3557 - val_acc: 0.8666
# Epoch 10/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3184 - acc: 0.8874 - val_loss: 0.3388 - val_acc: 0.8722
# Epoch 11/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2986 - acc: 0.8925 - val_loss: 0.3256 - val_acc: 0.8736
# Epoch 12/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2823 - acc: 0.8970 - val_loss: 0.3162 - val_acc: 0.8736
# Epoch 13/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2680 - acc: 0.9024 - val_loss: 0.3078 - val_acc: 0.8764
# Epoch 14/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2556 - acc: 0.9055 - val_loss: 0.2999 - val_acc: 0.8812
# Epoch 15/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2447 - acc: 0.9092 - val_loss: 0.2950 - val_acc: 0.8800
# Epoch 16/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2347 - acc: 0.9136 - val_loss: 0.2903 - val_acc: 0.8842
# Epoch 17/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2259 - acc: 0.9161 - val_loss: 0.2874 - val_acc: 0.8844
# Epoch 18/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2180 - acc: 0.9183 - val_loss: 0.2842 - val_acc: 0.8870
# Epoch 19/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2107 - acc: 0.9221 - val_loss: 0.2817 - val_acc: 0.8890
# Epoch 20/20
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2039 - acc: 0.9243 - val_loss: 0.2802 - val_acc: 0.8882

# %% [markdown]
# ## RNN
# ---

# %% [markdown]
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image6_f6vds6.png width=800>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.SimpleRNN(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'FCNwithGAP')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 5, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "FCNwithGAP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256)]             0
#
#  embedding_3 (Embedding)     (None, 256, 32)           320000
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 322,113
# Trainable params: 322,113
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 157/157 [==============================] - 38s 236ms/step - loss: 0.6923 - acc: 0.5098 - val_loss: 0.6934 - val_acc: 0.5278
# Epoch 2/5
# 157/157 [==============================] - 37s 235ms/step - loss: 0.6617 - acc: 0.5821 - val_loss: 0.6871 - val_acc: 0.5234
# Epoch 3/5
# 157/157 [==============================] - 37s 237ms/step - loss: 0.5981 - acc: 0.6342 - val_loss: 0.7300 - val_acc: 0.5142
# Epoch 4/5
# 157/157 [==============================] - 38s 242ms/step - loss: 0.5298 - acc: 0.6784 - val_loss: 0.7363 - val_acc: 0.5152
# Epoch 5/5
# 157/157 [==============================] - 37s 238ms/step - loss: 0.4801 - acc: 0.7136 - val_loss: 0.7709 - val_acc: 0.5112

# %% [markdown]
# ## LSTM
# ---
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image3_nsnxp3.png width=600>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.LSTM(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y)
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 256)]             0
#
#  embedding_6 (Embedding)     (None, 256, 32)           320000
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 328,353
# Trainable params: 328,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 7s 17ms/step - loss: 0.6854 - acc: 0.5521 - val_loss: 0.5969 - val_acc: 0.6816
# Epoch 2/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5714 - acc: 0.7347 - val_loss: 0.5168 - val_acc: 0.7872
# Epoch 3/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4572 - acc: 0.8170 - val_loss: 0.4162 - val_acc: 0.8394
# Epoch 4/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4437 - acc: 0.8338 - val_loss: 0.4902 - val_acc: 0.8122
# Epoch 5/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.3751 - acc: 0.8709 - val_loss: 0.3801 - val_acc: 0.8618
# Epoch 6/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.3546 - acc: 0.8784 - val_loss: 0.5094 - val_acc: 0.8322
# Epoch 7/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3069 - acc: 0.9014 - val_loss: 0.6742 - val_acc: 0.7174
# Epoch 8/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2881 - acc: 0.9085 - val_loss: 0.3406 - val_acc: 0.8810
# Epoch 9/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2580 - acc: 0.9200 - val_loss: 0.6555 - val_acc: 0.7954
# Epoch 10/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2448 - acc: 0.9251 - val_loss: 0.3611 - val_acc: 0.8794
# Epoch 11/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2246 - acc: 0.9297 - val_loss: 0.5191 - val_acc: 0.8500
# Epoch 12/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2240 - acc: 0.9299 - val_loss: 0.4119 - val_acc: 0.8576
# Epoch 13/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2390 - acc: 0.9233 - val_loss: 0.3492 - val_acc: 0.8754
# Epoch 14/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2110 - acc: 0.9351 - val_loss: 0.3586 - val_acc: 0.8666
# Epoch 15/20
# 157/157 [==============================] - 3s 18ms/step - loss: 0.2054 - acc: 0.9384 - val_loss: 0.4253 - val_acc: 0.8662
# Epoch 16/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2080 - acc: 0.9350 - val_loss: 0.3626 - val_acc: 0.8566
# Epoch 17/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2225 - acc: 0.9313 - val_loss: 0.3778 - val_acc: 0.8646
# Epoch 18/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2065 - acc: 0.9365 - val_loss: 0.3782 - val_acc: 0.8580
# Epoch 19/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2120 - acc: 0.9383 - val_loss: 0.4093 - val_acc: 0.8684
# Epoch 20/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.2137 - acc: 0.9342 - val_loss: 0.3898 - val_acc: 0.8700

# %% [markdown]
# ### | **many-to-many**
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image9_e1gwba.png width=700>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.LSTM(32, return_sequences = True)(y) # 2차 텐서가 출력된다 / many to many
y = layers.LSTM(32, return_sequences = False)(y) # 1차 텐서가 출력된다 / many to one
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 256)]             0
#
#  embedding_10 (Embedding)    (None, 256, 32)           320000
#
#  lstm_6 (LSTM)               (None, 256, 32)           8320
#
#  lstm_7 (LSTM)               (None, 32)                8320
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 336,673
# Trainable params: 336,673
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 8s 30ms/step - loss: 0.6639 - acc: 0.5770 - val_loss: 0.5372 - val_acc: 0.7690
# Epoch 2/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.5211 - acc: 0.7688 - val_loss: 0.5754 - val_acc: 0.6912
# Epoch 3/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.4169 - acc: 0.8278 - val_loss: 0.4058 - val_acc: 0.8392
# Epoch 4/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3765 - acc: 0.8554 - val_loss: 0.3903 - val_acc: 0.8502
# Epoch 5/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.3344 - acc: 0.8760 - val_loss: 0.3346 - val_acc: 0.8730
# Epoch 6/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2980 - acc: 0.8954 - val_loss: 0.4438 - val_acc: 0.8504
# Epoch 7/20
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2616 - acc: 0.9104 - val_loss: 0.5625 - val_acc: 0.7962
# Epoch 8/20
# 157/157 [==============================] - 4s 28ms/step - loss: 0.2447 - acc: 0.9183 - val_loss: 0.6146 - val_acc: 0.8146
# Epoch 9/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2256 - acc: 0.9280 - val_loss: 0.3700 - val_acc: 0.8638
# Epoch 10/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2308 - acc: 0.9266 - val_loss: 0.6062 - val_acc: 0.6738
# Epoch 11/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2503 - acc: 0.8944 - val_loss: 0.3479 - val_acc: 0.8632
# Epoch 12/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2119 - acc: 0.9316 - val_loss: 0.3982 - val_acc: 0.8580
# Epoch 13/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2677 - acc: 0.9011 - val_loss: 0.5673 - val_acc: 0.7002
# Epoch 14/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2958 - acc: 0.8832 - val_loss: 0.3969 - val_acc: 0.8372
# Epoch 15/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2168 - acc: 0.9258 - val_loss: 0.4714 - val_acc: 0.8628
# Epoch 16/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2110 - acc: 0.9252 - val_loss: 0.4096 - val_acc: 0.8580
# Epoch 17/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.2090 - acc: 0.9305 - val_loss: 0.4855 - val_acc: 0.8102
# Epoch 18/20
# 157/157 [==============================] - 4s 25ms/step - loss: 0.2054 - acc: 0.9317 - val_loss: 0.3945 - val_acc: 0.8514
# Epoch 19/20
# 157/157 [==============================] - 4s 25ms/step - loss: 0.2223 - acc: 0.9287 - val_loss: 0.5447 - val_acc: 0.8254
# Epoch 20/20
# 157/157 [==============================] - 4s 25ms/step - loss: 0.2423 - acc: 0.9197 - val_loss: 0.3856 - val_acc: 0.8594

# %% [markdown]
# ## GRU
# ---
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image10_zgefie.png width=600>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GRU(32)(y)
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 256)]             0
#
#  embedding_11 (Embedding)    (None, 256, 32)           320000
#
#  gru (GRU)                   (None, 32)                6336
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 326,369
# Trainable params: 326,369
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 4s 17ms/step - loss: 0.6886 - acc: 0.5250 - val_loss: 0.6694 - val_acc: 0.5620
# Epoch 2/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.6639 - acc: 0.6036 - val_loss: 0.6443 - val_acc: 0.5842
# Epoch 3/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.6067 - acc: 0.6585 - val_loss: 0.6603 - val_acc: 0.5794
# Epoch 4/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.5954 - acc: 0.7466 - val_loss: 0.5110 - val_acc: 0.8026
# Epoch 5/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4697 - acc: 0.8117 - val_loss: 0.6556 - val_acc: 0.7294
# Epoch 6/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4356 - acc: 0.8284 - val_loss: 0.4500 - val_acc: 0.8170
# Epoch 7/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.4045 - acc: 0.8504 - val_loss: 0.4276 - val_acc: 0.8342
# Epoch 8/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4203 - acc: 0.8453 - val_loss: 0.4448 - val_acc: 0.8390
# Epoch 9/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3821 - acc: 0.8645 - val_loss: 0.4288 - val_acc: 0.8348
# Epoch 10/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3822 - acc: 0.8671 - val_loss: 0.4187 - val_acc: 0.8406
# Epoch 11/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3477 - acc: 0.8806 - val_loss: 0.6421 - val_acc: 0.7872
# Epoch 12/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3624 - acc: 0.8773 - val_loss: 0.4198 - val_acc: 0.8464
# Epoch 13/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3405 - acc: 0.8841 - val_loss: 0.4273 - val_acc: 0.8444
# Epoch 14/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3184 - acc: 0.8957 - val_loss: 0.4196 - val_acc: 0.8500
# Epoch 15/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3261 - acc: 0.8924 - val_loss: 0.4097 - val_acc: 0.8498
# Epoch 16/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.3225 - acc: 0.8936 - val_loss: 0.4128 - val_acc: 0.8480
# Epoch 17/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.3118 - acc: 0.8990 - val_loss: 0.4136 - val_acc: 0.8530
# Epoch 18/20
# 157/157 [==============================] - 2s 14ms/step - loss: 0.3056 - acc: 0.9028 - val_loss: 0.4364 - val_acc: 0.8364
# Epoch 19/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2917 - acc: 0.9071 - val_loss: 0.4461 - val_acc: 0.8318
# Epoch 20/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2870 - acc: 0.9062 - val_loss: 0.4122 - val_acc: 0.8490

# %% [markdown]
# ### | **many-to-many**
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image9_e1gwba.png width=700>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape = MAX_LEN)
y = layers.Embedding(MAX_FEATURES, EMB_DIMS )(x)
y = layers.GRU(32, return_sequences = True)(y)
y = layers.GRU(32, return_sequences = False)(y)
y = layers.Dense(1, activation = 'sigmoid')(y) 
model = models.Model(x, y, name = 'LSTM')
model.summary()

model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs = 20, 
                    batch_size = 128,
                    validation_split = 0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 256)]             0
#
#  embedding_12 (Embedding)    (None, 256, 32)           320000
#
#  gru_1 (GRU)                 (None, 256, 32)           6336
#
#  gru_2 (GRU)                 (None, 32)                6336
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 332,705
# Trainable params: 332,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 8s 29ms/step - loss: 0.6826 - acc: 0.5293 - val_loss: 0.6648 - val_acc: 0.5690
# Epoch 2/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.6655 - acc: 0.6360 - val_loss: 0.5475 - val_acc: 0.7680
# Epoch 3/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.5497 - acc: 0.7454 - val_loss: 0.5656 - val_acc: 0.6720
# Epoch 4/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.5319 - acc: 0.7483 - val_loss: 0.4395 - val_acc: 0.8324
# Epoch 5/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.4381 - acc: 0.8195 - val_loss: 0.3902 - val_acc: 0.8526
# Epoch 6/20
# 157/157 [==============================] - 3s 21ms/step - loss: 0.3658 - acc: 0.8681 - val_loss: 0.3664 - val_acc: 0.8660
# Epoch 7/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3500 - acc: 0.8756 - val_loss: 0.3981 - val_acc: 0.8524
# Epoch 8/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3272 - acc: 0.8866 - val_loss: 0.3774 - val_acc: 0.8576
# Epoch 9/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2993 - acc: 0.9009 - val_loss: 0.3854 - val_acc: 0.8688
# Epoch 10/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3249 - acc: 0.8825 - val_loss: 0.4773 - val_acc: 0.8062
# Epoch 11/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2736 - acc: 0.9105 - val_loss: 0.3982 - val_acc: 0.8586
# Epoch 12/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2535 - acc: 0.9169 - val_loss: 0.3608 - val_acc: 0.8726
# Epoch 13/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.2247 - acc: 0.9273 - val_loss: 0.3357 - val_acc: 0.8762
# Epoch 14/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1976 - acc: 0.9348 - val_loss: 0.5843 - val_acc: 0.8466
# Epoch 15/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1752 - acc: 0.9382 - val_loss: 0.3471 - val_acc: 0.8728
# Epoch 16/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1572 - acc: 0.9456 - val_loss: 0.3267 - val_acc: 0.8682
# Epoch 17/20
# 157/157 [==============================] - 4s 25ms/step - loss: 0.1467 - acc: 0.9510 - val_loss: 0.3683 - val_acc: 0.8786
# Epoch 18/20
# 157/157 [==============================] - 4s 23ms/step - loss: 0.1316 - acc: 0.9568 - val_loss: 0.3830 - val_acc: 0.8636
# Epoch 19/20
# 157/157 [==============================] - 3s 22ms/step - loss: 0.1198 - acc: 0.9613 - val_loss: 0.3503 - val_acc: 0.8692
# Epoch 20/20
# 157/157 [==============================] - 3s 21ms/step - loss: 0.1085 - acc: 0.9637 - val_loss: 0.4275 - val_acc: 0.8752
