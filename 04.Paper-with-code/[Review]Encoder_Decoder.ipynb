# %% [markdown]
# <a href="https://colab.research.google.com/github/PomesHouse/SkillTreePython-DeepLearning/blob/main/04.Paper-with-code/%5BReview%5DEncoder_Decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Encoder-Decoder
# ---

# %% [markdown]
# 참고
#
# https://towardsdatascience.com/what-is-an-encoder-decoder-model-86b3d57c5e1a

# %% [markdown]
# **When to use?**
# * Image Captioning
# * Sentiment Analysis
# * Translation

# %% [markdown]
# ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# 1. Encoder
# * Converts data into a required format
# * The encoder is built by stacking recurrent neural network (RNN) since the structure of this type of layer allows the model to understand context and temporal dependencies of the sequences.
# * The output of the encoder, the hidden state, is the state of the last RNN timestep.

# %% [markdown]
# 2. Hidden State
# * The output of the encoder, a two-dimensional vector that encapsulates the whole meaning of the input sequence.
# * The length of the vector depends on the number of cells in the RNN.

# %% [markdown]
# 3. Decoder
# * Converts two-dimensional vector into the output sequence.
# * Built with RNN layers and a dense layer to predict the output.
